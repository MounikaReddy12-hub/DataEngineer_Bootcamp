# %% [markdown]
# # File Handling

# %%
#Read a file using read mode
import csv

with open('/Workspace/Users/reddymounika7860@gmail.com/DataEngineer_Bootcamp/customers-1000.csv', mode='r') as file:
  reader = csv.reader(file)
  #next will skip the header
  next(reader)
  for row in reader:
    print(row)

# %%
import csv

with open('customers-1000.csv', mode='r') as file:
  reader = csv.reader(file)
  for row in reader:
      print(row)

# %%
import csv

with open('customers-1000.csv',mode='r') as dictfile:
    reader=csv.DictReader(dictfile)
    for row in reader:
        print(row['First Name'])

# %%
#Write first name into a sepearte csv file
import csv

with open('newoutput.csv', mode='w') as file:
    writer = csv.writer(file)
    writer.writerow(['First Name'])

# %%
import csv
with open('newoutput.csv', mode='r') as dictfile:
        reader = csv.reader(dictfile)
        for row in reader:
            print(row)

# %% [markdown]
# ### Reading Txt file and print where the false at line number

# %%
with open('log.txt', mode='r') as logfile:
    for line in logfile:
        print(line)

# %%
with open('log.txt', mode='r') as logfile:
    count = 0
    for line in logfile:
        if 'False' in line:
            print(f"Alert at line {count}:{line.strip()}")
        count+=1
